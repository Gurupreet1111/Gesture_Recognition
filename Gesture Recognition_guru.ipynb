# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
# !git clone https://github.com/Gurupreet1111/Gesture_Recognition.git
# Out:
# Cloning into 'Gesture_Recognition'...
# remote: Enumerating objects: 23546, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 23546 (delta 6), reused 9 (delta 1), pack-reused 23526
# Receiving objects: 100% (23546/23546), 1.58 GiB | 30.47 MiB/s, done.
# Resolving deltas: 100% (7/7), done.
# Updating files: 100% (22895/22895), done.

# %%
import numpy as np
import os
#from scipy.misc.pilutil import imread, imresize
import cv2

from imageio.v2 import imread

import datetime
import os
from PIL import Image, ImageFilter, ImageEnhance
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
import os
os.environ['PYTHONHASHSEED']="30"
np.random.seed(30)
import random as rn
rn.seed(30)
import tensorflow as tf
tf.random.set_seed(30)
from keras import backend as K

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
# train and validatiaon data creator with ablation
# when ablation is 10, then 10 folders for each label will be selected.
def get_data(path, ablation=None):
    train_doc = np.random.permutation(open(path+'train.csv').readlines())
    val_doc = np.random.permutation(open(path+'val.csv').readlines())
    counts = np.zeros(5) # count for loading folders for 5 classes
    train_data = []
    val_data = []
    # when ablation is None pass full training and val data
    if ablation is not None:
        # iterating train doc
        for doc in train_doc:
            lable = int(doc.strip().split(';')[2])
            if counts[lable] < ablation:
                train_data.append(doc)
                counts[lable] += 1
        counts = np.zeros(5)
        # iterating val doc
        for doc in val_doc:
            lable = int(doc.strip().split(';')[2])
            if counts[lable] < ablation:
                val_data.append(doc)
                counts[lable] += 1
    else:
        train_data, val_data = train_doc, val_doc
    return train_data, val_data

# %%
train_doc, val_doc = get_data('Gesture_Recognition/Project_data/', ablation=None)
batch_size = 32 # experiment with the batch size
enable_augmentation = False # augmentation of Data
# sequence ids
# selecting alternate frames from 7 to 26.
seq_idx = range(7,26,2)
# image dimensions
dim_x, dim_y = 120, 120

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
# generator with augmentation for train data
def generator(source_path, folder_list, batch_size, is_train = False, augmention = False, debug=False):
    # print('\nSource path = ', source_path, '; batch size =', batch_size)
    img_idx = seq_idx #create a list of image numbers you want to use for a particular video
    x = len(img_idx)
    y, z = dim_x, dim_y
    while True:
        # doubling the data for augmentation
        if is_train and augmention:
            t = np.concatenate((np.random.permutation(folder_list), np.random.permutation(folder_list)))
        else:
            t = np.random.permutation(folder_list)

        if (len(t)%batch_size) == 0:
            num_batches = int(len(t)/batch_size)
        else:
            num_batches = len(t)//batch_size + 1

        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                if debug:
                    plt.figure(figsize=(20,5))
                #handling remaining datapoints
                folder_idx = folder + (batch*batch_size)
                if folder_idx >= len(t):
                    break
                folder_str = t[folder_idx]
                imgs = os.listdir(source_path+'/'+ folder_str.split(';')[0]) # read all the images in the folder
                # randomly enabling augmentation and augmentation type
                aug_type = None
                if is_train and augmention and rn.randint(0,1) == 1:
                    aug_type = rn.randint(0, 4) #randomly selecting augmentation type
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ folder_str.strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                    # plotting original images for debugging purpose only
                    if debug:
                        plt.subplot(2, x, idx+1)
                        plt.imshow(image.astype('uint8'))

                    #crop the images and resize them. Note that the images are of 2 different shape
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    # making the rectangle images into square by cropping sides
                    # so the aspect ration can be mantained while resizing.
                    if image.shape[1] > image.shape[0]:
                        diff_px = image.shape[1] - image.shape[0]
                        crop_start = diff_px//2
                        crop_end = crop_start + image.shape[0]
                        image = image[:, crop_start:crop_end]
                    elif image.shape[0] > image.shape[1]:
                        diff_px = image.shape[0] - image.shape[1]
                        crop_start = diff_px//2
                        crop_end = crop_start + image.shape[1]
                        image = image[:, crop_start:crop_end]
                    resized_im = cv2.resize(image, (y,z))

                    if aug_type is not None:
                        if aug_type == 0: # edge Enhancement
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.EDGE_ENHANCE))
                        elif aug_type == 1: # adding gaussian blur
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.GaussianBlur(1)))
                        elif aug_type == 2: # enchancing image detailing
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.DETAIL))
                        elif aug_type == 3: # sharpening image
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.SHARPEN))
                        elif aug_type == 4: # Brightness enhancement
                            resized_im = np.array(ImageEnhance.Brightness((Image.fromarray(resized_im, 'RGB'))).enhance(1.5))
                    # plotting rezised images for debugging purpose only
                    if debug:
                        plt.subplot(2, x, idx+x+1)
                        plt.imshow(resized_im)

                    batch_data[folder,idx,:,:,0] = resized_im[:,:,0]/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = resized_im[:,:,1]/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = resized_im[:,:,2]/255 #normalise and feed in the image

                batch_labels[folder, int(folder_str.strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = 'Gesture_Recognition/Project_data/train' #'/notebooks/storage/Final_data/Collated_training/train'
val_path =  'Gesture_Recognition/Project_data/val' #'/notebooks/storage/Final_data/Collated_training/val'

#multiply number train seq by 2 when using augmentation
multiplier = 1
if enable_augmentation:
    multiplier = 2
num_train_sequences = len(train_doc)*multiplier
print('# training sequences =', num_train_sequences)

num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)

num_epochs = 50 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 50

# %%
# testing generative
test_gen = generator(train_path, train_doc, 1, is_train = True, augmention = True, debug = True)
d = next(test_gen)[0]

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Bidirectional, BatchNormalization, Activation, Dropout, GlobalAveragePooling2D, GlobalAveragePooling3D, ConvLSTM2D
from keras.layers import Conv2D, Conv3D, MaxPooling2D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers

#input shape for the st layer
input_shape = (len(seq_idx), dim_x, dim_y, 3)
np.random.seed(30)

# %% [markdown]
# ### Experiment - 1 & 2
# **Conv3D**

# %%
model = Sequential()
model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
model.add(MaxPooling3D(pool_size=2))

model.add(Conv3D(64, kernel_size=3, activation='relu'))
model.add(MaxPooling3D(pool_size=2))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 3
# **Conv3D**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Conv3D(256, kernel_size=(3, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(3, 2, 2)))

# model.add(Conv3D(512, kernel_size=(3, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(3, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 4
# **Conv3D**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))

# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 5 & 6
# **Conv3D**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())

# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 7 & 8
# **Conv3D**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())
# #model.add(Dropout(0.2))
# model.add(Dropout(0.5))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# #model.add(Dropout(0.2))
# model.add(Dropout(0.5))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# #model.add(Dropout(0.2))
# model.add(Dropout(0.5))

# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# #model.add(Dropout(0.2))
# model.add(Dropout(0.5))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 9
# **Conv3D**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 10
# **Conv3D**

# %%
# loss: 0.1388 - categorical_accuracy: 0.9539 - val_loss: 0.1661 - val_categorical_accuracy: 0.9297
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(GlobalAveragePooling3D())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 11
# **TimeDistributed Conv2D + GRU**

# %%
# model = Sequential()
# model.add(TimeDistributed(
#     Conv2D(32, (3,3), activation='relu'), input_shape=input_shape)
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())

# model.add(TimeDistributed(
#     Conv2D(64, (3,3), activation='relu'))
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())

# model.add(TimeDistributed(GlobalAveragePooling2D()))
# model.add(TimeDistributed(Dense(64, activation='relu')))
# model.add(BatchNormalization())

# model.add(GRU(128))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 12
# **TimeDistributed Conv2D + GRU**

# %%
# model = Sequential()
# model.add(TimeDistributed(
#     Conv2D(32, (3,3), activation='relu'), input_shape=input_shape)
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(TimeDistributed(
#     Conv2D(64, (3,3), activation='relu'))
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(TimeDistributed(GlobalAveragePooling2D()))
# model.add(TimeDistributed(Dense(64, activation='relu')))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(GRU(128))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 13
# **TimeDistributed Conv2D + Dense**

# %%
# model = Sequential()
# model.add(TimeDistributed(
#     Conv2D(32, (3,3), activation='relu'), input_shape=input_shape)
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())

# model.add(TimeDistributed(
#     Conv2D(64, (3,3), activation='relu'))
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())

# model.add(TimeDistributed(
#     Conv2D(128, (3,3), activation='relu'))
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())

# model.add(GlobalAveragePooling3D())
# model.add(Dense(256, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 14
# **TimeDistributed + ConvLSTM2D**

# %%
# model = Sequential()
# model.add(TimeDistributed(
#     Conv2D(8, (3,3), activation='relu'), input_shape=input_shape)
# )
# model.add(BatchNormalization())
# model.add(TimeDistributed(
#     Conv2D(16, (3,3), activation='relu'))
# )
# model.add(BatchNormalization())
# model.add(
#     ConvLSTM2D(8, kernel_size = 3, return_sequences=False)
# )
# model.add(BatchNormalization())
# model.add(TimeDistributed(
#     Dense(64, activation='relu'))
# )
# model.add(BatchNormalization())
# model.add(GlobalAveragePooling2D())
# model.add(Dense(64, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# # Final Model

# %%
model = Sequential()
model.add(TimeDistributed(
    Conv2D(8, (3,3), activation='relu'), input_shape=input_shape)
)
model.add(BatchNormalization())
model.add(TimeDistributed(
    Conv2D(16, (3,3), activation='relu'))
)
model.add(BatchNormalization())
model.add(
    ConvLSTM2D(8, kernel_size = 3, return_sequences=False)
)
model.add(BatchNormalization())
model.add(TimeDistributed(
    Dense(64, activation='relu'))
)
model.add(BatchNormalization())
model.add(GlobalAveragePooling2D())
model.add(Dense(64, activation='relu'))
model.add(Dense(5, activation='softmax'))

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = optimizers.Adam(lr=0.01) #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model.summary())
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDist  (None, 10, 118, 118, 8)   224
#  ributed)
#
#  batch_normalization (Batch  (None, 10, 118, 118, 8)   32
#  Normalization)
#
#  time_distributed_1 (TimeDi  (None, 10, 116, 116, 16   1168
#  stributed)                  )
#
#  batch_normalization_1 (Bat  (None, 10, 116, 116, 16   64
#  chNormalization)            )
#
#  conv_lstm2d (ConvLSTM2D)    (None, 114, 114, 8)       6944
#
#  batch_normalization_2 (Bat  (None, 114, 114, 8)       32
#  chNormalization)
#
#  time_distributed_2 (TimeDi  (None, 114, 114, 64)      576
#  stributed)
#
#  batch_normalization_3 (Bat  (None, 114, 114, 64)      256
#  chNormalization)
#
#  global_average_pooling2d (  (None, 64)                0
#  GlobalAveragePooling2D)
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 13781 (53.83 KB)
# Trainable params: 13589 (53.08 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________
# None

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size, is_train = True, augmention = enable_augmentation)
val_generator = generator(val_path, val_doc, batch_size)

# %%
curr_dt_time = datetime.datetime.now()
model_name = 'model_init_exp_16' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'

if not os.path.exists(model_name):
    os.mkdir(model_name)

filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001, verbose=1) # write the REducelronplateau code here

callbacks_list = [checkpoint, LR]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                        callbacks=callbacks_list, validation_data=val_generator,
                        validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/50
# 21/21 [==============================] - ETA: 0s - loss: 1.4839 - categorical_accuracy: 0.3140
# Epoch 1: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00001-1.48394-0.31399-1.25409-0.14062.h5
# 21/21 [==============================] - 618s 29s/step - loss: 1.4839 - categorical_accuracy: 0.3140 - val_loss: 1.2541 - val_categorical_accuracy: 0.1406 - lr: 0.0010
# Epoch 2/50
# 21/21 [==============================] - ETA: 0s - loss: 1.2978 - categorical_accuracy: 0.4479
# Epoch 2: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00002-1.29783-0.44792-1.24472-0.15625.h5
# 21/21 [==============================] - 570s 27s/step - loss: 1.2978 - categorical_accuracy: 0.4479 - val_loss: 1.2447 - val_categorical_accuracy: 0.1562 - lr: 0.0010
# Epoch 3/50
# 21/21 [==============================] - ETA: 0s - loss: 1.1860 - categorical_accuracy: 0.4851
# Epoch 3: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00003-1.18603-0.48512-1.25765-0.18750.h5
# 21/21 [==============================] - 569s 27s/step - loss: 1.1860 - categorical_accuracy: 0.4851 - val_loss: 1.2576 - val_categorical_accuracy: 0.1875 - lr: 0.0010
# Epoch 4/50
# 21/21 [==============================] - ETA: 0s - loss: 1.0660 - categorical_accuracy: 0.5491
# Epoch 4: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00004-1.06600-0.54911-1.32357-0.14844.h5
# 21/21 [==============================] - 566s 27s/step - loss: 1.0660 - categorical_accuracy: 0.5491 - val_loss: 1.3236 - val_categorical_accuracy: 0.1484 - lr: 0.0010
# Epoch 5/50
# 21/21 [==============================] - ETA: 0s - loss: 1.0582 - categorical_accuracy: 0.5640
# Epoch 5: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00005-1.05821-0.56399-1.31009-0.17188.h5
# 21/21 [==============================] - 574s 27s/step - loss: 1.0582 - categorical_accuracy: 0.5640 - val_loss: 1.3101 - val_categorical_accuracy: 0.1719 - lr: 0.0010
# Epoch 6/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9385 - categorical_accuracy: 0.6146
# Epoch 6: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00006-0.93850-0.61458-1.35140-0.10938.h5
# 21/21 [==============================] - 566s 27s/step - loss: 0.9385 - categorical_accuracy: 0.6146 - val_loss: 1.3514 - val_categorical_accuracy: 0.1094 - lr: 0.0010
# Epoch 7/50
# 21/21 [==============================] - ETA: 0s - loss: 0.9246 - categorical_accuracy: 0.6012
# Epoch 7: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00007-0.92461-0.60119-1.31861-0.21875.h5
# 21/21 [==============================] - 548s 26s/step - loss: 0.9246 - categorical_accuracy: 0.6012 - val_loss: 1.3186 - val_categorical_accuracy: 0.2188 - lr: 0.0010
# Epoch 8/50
# 21/21 [==============================] - ETA: 0s - loss: 0.8439 - categorical_accuracy: 0.6473
# Epoch 8: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00008-0.84390-0.64732-1.40321-0.22656.h5
# 21/21 [==============================] - 562s 27s/step - loss: 0.8439 - categorical_accuracy: 0.6473 - val_loss: 1.4032 - val_categorical_accuracy: 0.2266 - lr: 0.0010
# Epoch 9/50
# 21/21 [==============================] - ETA: 0s - loss: 0.7977 - categorical_accuracy: 0.6920
# Epoch 9: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00009-0.79774-0.69196-1.56160-0.17188.h5
# 21/21 [==============================] - 563s 27s/step - loss: 0.7977 - categorical_accuracy: 0.6920 - val_loss: 1.5616 - val_categorical_accuracy: 0.1719 - lr: 0.0010
# Epoch 10/50
# 21/21 [==============================] - ETA: 0s - loss: 0.7367 - categorical_accuracy: 0.6860
# Epoch 10: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00010-0.73670-0.68601-1.43922-0.25781.h5
# 21/21 [==============================] - 564s 27s/step - loss: 0.7367 - categorical_accuracy: 0.6860 - val_loss: 1.4392 - val_categorical_accuracy: 0.2578 - lr: 0.0010
# Epoch 11/50
# 21/21 [==============================] - ETA: 0s - loss: 0.7406 - categorical_accuracy: 0.6860
# Epoch 11: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00011-0.74059-0.68601-1.57901-0.24219.h5
# 21/21 [==============================] - 571s 27s/step - loss: 0.7406 - categorical_accuracy: 0.6860 - val_loss: 1.5790 - val_categorical_accuracy: 0.2422 - lr: 0.0010
# Epoch 12/50
# 21/21 [==============================] - ETA: 0s - loss: 0.7413 - categorical_accuracy: 0.7262
# Epoch 12: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00012-0.74131-0.72619-1.80730-0.14062.h5
# 21/21 [==============================] - 549s 26s/step - loss: 0.7413 - categorical_accuracy: 0.7262 - val_loss: 1.8073 - val_categorical_accuracy: 0.1406 - lr: 0.0010
# Epoch 13/50
# 21/21 [==============================] - ETA: 0s - loss: 0.6618 - categorical_accuracy: 0.7262
# Epoch 13: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00013-0.66182-0.72619-1.58572-0.21094.h5
# 21/21 [==============================] - 571s 27s/step - loss: 0.6618 - categorical_accuracy: 0.7262 - val_loss: 1.5857 - val_categorical_accuracy: 0.2109 - lr: 0.0010
# Epoch 14/50
# 21/21 [==============================] - ETA: 0s - loss: 0.6344 - categorical_accuracy: 0.7485
# Epoch 14: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00014-0.63439-0.74851-1.80376-0.18750.h5
# 21/21 [==============================] - 569s 27s/step - loss: 0.6344 - categorical_accuracy: 0.7485 - val_loss: 1.8038 - val_categorical_accuracy: 0.1875 - lr: 0.0010
# Epoch 15/50
# 21/21 [==============================] - ETA: 0s - loss: 0.6382 - categorical_accuracy: 0.7500
# Epoch 15: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00015-0.63824-0.75000-1.92830-0.22656.h5
# 21/21 [==============================] - 567s 27s/step - loss: 0.6382 - categorical_accuracy: 0.7500 - val_loss: 1.9283 - val_categorical_accuracy: 0.2266 - lr: 0.0010
# Epoch 16/50
# 21/21 [==============================] - ETA: 0s - loss: 0.6016 - categorical_accuracy: 0.7440
# Epoch 16: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00016-0.60156-0.74405-1.71974-0.28125.h5
# 21/21 [==============================] - 564s 27s/step - loss: 0.6016 - categorical_accuracy: 0.7440 - val_loss: 1.7197 - val_categorical_accuracy: 0.2812 - lr: 0.0010
# Epoch 17/50
# 21/21 [==============================] - ETA: 0s - loss: 0.6116 - categorical_accuracy: 0.7485
# Epoch 17: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00017-0.61157-0.74851-1.83810-0.43750.h5
# 21/21 [==============================] - 566s 27s/step - loss: 0.6116 - categorical_accuracy: 0.7485 - val_loss: 1.8381 - val_categorical_accuracy: 0.4375 - lr: 0.0010
# Epoch 18/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5862 - categorical_accuracy: 0.7560
# Epoch 18: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00018-0.58618-0.75595-1.51889-0.53125.h5
# 21/21 [==============================] - 562s 27s/step - loss: 0.5862 - categorical_accuracy: 0.7560 - val_loss: 1.5189 - val_categorical_accuracy: 0.5312 - lr: 0.0010
# Epoch 19/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5717 - categorical_accuracy: 0.7857
# Epoch 19: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00019-0.57175-0.78571-1.41961-0.53906.h5
# 21/21 [==============================] - 570s 27s/step - loss: 0.5717 - categorical_accuracy: 0.7857 - val_loss: 1.4196 - val_categorical_accuracy: 0.5391 - lr: 0.0010
# Epoch 20/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5937 - categorical_accuracy: 0.7381
# Epoch 20: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00020-0.59373-0.73810-1.43725-0.50000.h5
# 21/21 [==============================] - 563s 27s/step - loss: 0.5937 - categorical_accuracy: 0.7381 - val_loss: 1.4372 - val_categorical_accuracy: 0.5000 - lr: 0.0010
# Epoch 21/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5839 - categorical_accuracy: 0.7470
# Epoch 21: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00021-0.58394-0.74702-0.92161-0.60938.h5
# 21/21 [==============================] - 567s 27s/step - loss: 0.5839 - categorical_accuracy: 0.7470 - val_loss: 0.9216 - val_categorical_accuracy: 0.6094 - lr: 0.0010
# Epoch 22/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5585 - categorical_accuracy: 0.7961
# Epoch 22: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00022-0.55854-0.79613-1.54630-0.51562.h5
# 21/21 [==============================] - 552s 26s/step - loss: 0.5585 - categorical_accuracy: 0.7961 - val_loss: 1.5463 - val_categorical_accuracy: 0.5156 - lr: 0.0010
# Epoch 23/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5032 - categorical_accuracy: 0.7857
# Epoch 23: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00023-0.50321-0.78571-0.92470-0.57812.h5
# 21/21 [==============================] - 538s 26s/step - loss: 0.5032 - categorical_accuracy: 0.7857 - val_loss: 0.9247 - val_categorical_accuracy: 0.5781 - lr: 0.0010
# Epoch 24/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5113 - categorical_accuracy: 0.8065
# Epoch 24: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00024-0.51128-0.80655-0.93994-0.56250.h5
# 21/21 [==============================] - 555s 27s/step - loss: 0.5113 - categorical_accuracy: 0.8065 - val_loss: 0.9399 - val_categorical_accuracy: 0.5625 - lr: 0.0010
# Epoch 25/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4984 - categorical_accuracy: 0.7991
# Epoch 25: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00025-0.49845-0.79911-1.64038-0.52344.h5
# 21/21 [==============================] - 565s 27s/step - loss: 0.4984 - categorical_accuracy: 0.7991 - val_loss: 1.6404 - val_categorical_accuracy: 0.5234 - lr: 0.0010
# Epoch 26/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5069 - categorical_accuracy: 0.7738
# Epoch 26: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00026-0.50694-0.77381-0.59887-0.75000.h5
# 21/21 [==============================] - 553s 26s/step - loss: 0.5069 - categorical_accuracy: 0.7738 - val_loss: 0.5989 - val_categorical_accuracy: 0.7500 - lr: 0.0010
# Epoch 27/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4492 - categorical_accuracy: 0.8274
# Epoch 27: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00027-0.44923-0.82738-1.27893-0.52344.h5
# 21/21 [==============================] - 557s 27s/step - loss: 0.4492 - categorical_accuracy: 0.8274 - val_loss: 1.2789 - val_categorical_accuracy: 0.5234 - lr: 0.0010
# Epoch 28/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5036 - categorical_accuracy: 0.7842
# Epoch 28: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00028-0.50361-0.78423-0.81556-0.67188.h5
# 21/21 [==============================] - 555s 27s/step - loss: 0.5036 - categorical_accuracy: 0.7842 - val_loss: 0.8156 - val_categorical_accuracy: 0.6719 - lr: 0.0010
# Epoch 29/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5029 - categorical_accuracy: 0.7872
# Epoch 29: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00029-0.50288-0.78720-1.07907-0.64062.h5
# 21/21 [==============================] - 540s 26s/step - loss: 0.5029 - categorical_accuracy: 0.7872 - val_loss: 1.0791 - val_categorical_accuracy: 0.6406 - lr: 0.0010
# Epoch 30/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4771 - categorical_accuracy: 0.8080
# Epoch 30: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00030-0.47709-0.80804-0.87267-0.71875.h5
# 21/21 [==============================] - 541s 26s/step - loss: 0.4771 - categorical_accuracy: 0.8080 - val_loss: 0.8727 - val_categorical_accuracy: 0.7188 - lr: 0.0010
# Epoch 31/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4557 - categorical_accuracy: 0.8229
# Epoch 31: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00031-0.45565-0.82292-0.57324-0.78125.h5
# 21/21 [==============================] - 567s 27s/step - loss: 0.4557 - categorical_accuracy: 0.8229 - val_loss: 0.5732 - val_categorical_accuracy: 0.7812 - lr: 0.0010
# Epoch 32/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4374 - categorical_accuracy: 0.8036
# Epoch 32: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00032-0.43736-0.80357-0.67272-0.71094.h5
# 21/21 [==============================] - 559s 27s/step - loss: 0.4374 - categorical_accuracy: 0.8036 - val_loss: 0.6727 - val_categorical_accuracy: 0.7109 - lr: 0.0010
# Epoch 33/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4660 - categorical_accuracy: 0.7961
# Epoch 33: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00033-0.46600-0.79613-0.83845-0.65625.h5
# 21/21 [==============================] - 559s 27s/step - loss: 0.4660 - categorical_accuracy: 0.7961 - val_loss: 0.8384 - val_categorical_accuracy: 0.6562 - lr: 0.0010
# Epoch 34/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4699 - categorical_accuracy: 0.7991
# Epoch 34: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00034-0.46989-0.79911-0.77361-0.68750.h5
# 21/21 [==============================] - 561s 27s/step - loss: 0.4699 - categorical_accuracy: 0.7991 - val_loss: 0.7736 - val_categorical_accuracy: 0.6875 - lr: 0.0010
# Epoch 35/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4585 - categorical_accuracy: 0.8185
# Epoch 35: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00035-0.45852-0.81845-0.65793-0.68750.h5
# 21/21 [==============================] - 563s 27s/step - loss: 0.4585 - categorical_accuracy: 0.8185 - val_loss: 0.6579 - val_categorical_accuracy: 0.6875 - lr: 0.0010
# Epoch 36/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4231 - categorical_accuracy: 0.8289
# Epoch 36: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00036-0.42314-0.82887-0.87967-0.66406.h5
# 21/21 [==============================] - 563s 27s/step - loss: 0.4231 - categorical_accuracy: 0.8289 - val_loss: 0.8797 - val_categorical_accuracy: 0.6641 - lr: 0.0010
# Epoch 37/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4456 - categorical_accuracy: 0.8185
# Epoch 37: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00037-0.44559-0.81845-0.72604-0.75781.h5
# 21/21 [==============================] - 563s 27s/step - loss: 0.4456 - categorical_accuracy: 0.8185 - val_loss: 0.7260 - val_categorical_accuracy: 0.7578 - lr: 0.0010
# Epoch 38/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4455 - categorical_accuracy: 0.8065
# Epoch 38: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00038-0.44545-0.80655-0.93143-0.67969.h5
# 21/21 [==============================] - 561s 27s/step - loss: 0.4455 - categorical_accuracy: 0.8065 - val_loss: 0.9314 - val_categorical_accuracy: 0.6797 - lr: 0.0010
# Epoch 39/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4526 - categorical_accuracy: 0.8170
# Epoch 39: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00039-0.45262-0.81696-1.47777-0.53906.h5
# 21/21 [==============================] - 561s 27s/step - loss: 0.4526 - categorical_accuracy: 0.8170 - val_loss: 1.4778 - val_categorical_accuracy: 0.5391 - lr: 0.0010
# Epoch 40/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5065 - categorical_accuracy: 0.7693
# Epoch 40: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00040-0.50647-0.76935-2.00270-0.53906.h5
# 21/21 [==============================] - 563s 27s/step - loss: 0.5065 - categorical_accuracy: 0.7693 - val_loss: 2.0027 - val_categorical_accuracy: 0.5391 - lr: 0.0010
# Epoch 41/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4460 - categorical_accuracy: 0.8170
# Epoch 41: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00041-0.44600-0.81696-0.78477-0.73438.h5
# 21/21 [==============================] - 550s 26s/step - loss: 0.4460 - categorical_accuracy: 0.8170 - val_loss: 0.7848 - val_categorical_accuracy: 0.7344 - lr: 0.0010
# Epoch 42/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4828 - categorical_accuracy: 0.7887
# Epoch 42: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00042-0.48280-0.78869-1.83562-0.53906.h5
# 21/21 [==============================] - 564s 27s/step - loss: 0.4828 - categorical_accuracy: 0.7887 - val_loss: 1.8356 - val_categorical_accuracy: 0.5391 - lr: 0.0010
# Epoch 43/50
# 21/21 [==============================] - ETA: 0s - loss: 0.4209 - categorical_accuracy: 0.8363
# Epoch 43: saving model to model_init_exp_16_2024-04-0803_36_23.045995/model-00043-0.42088-0.83631-0.73027-0.74219.h5
# 21/21 [==============================] - 562s 27s/step - loss: 0.4209 - categorical_accuracy: 0.8363 - val_loss: 0.7303 - val_categorical_accuracy: 0.7422 - lr: 0.0010
# Epoch 44/50

# %%
# plt.figure(figsize=(20,6))
# ax1 = plt.subplot(121)
# ax1 = plt.plot(history.history['loss'])
# ax1 = plt.plot(history.history['val_loss'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'validation'], loc='lower left')
# ax2 = plt.subplot(122)
# ax2 = plt.plot(history.history['categorical_accuracy'])
# ax2 = plt.plot(history.history['val_categorical_accuracy'])
# plt.title('model accuracy')
# plt.ylabel('categorical_accuracy')
# plt.xlabel('epoch')
# plt.legend(['train', 'validation'], loc='lower left')

# %%
# Exp 2

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation,Dropout,GlobalAveragePooling3D,GRU,GlobalAveragePooling2D,LSTM,MaxPool2D,ConvLSTM2D,GlobalAveragePooling1D
from keras.layers import Conv3D, MaxPooling3D,Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers
from keras.applications import MobileNet

# %%
def generator(source_path, folder_list, batch_size):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    img_idx =[x for x in range(0,image_count)]
    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(t)//batch_size    # calculate the number of batches
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,image_count,image_width,image_height,channels)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,num_classes)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                    #crop the images and resize them. Note that the images are of 2 different shape
                    #and the conv3D will throw error if the inputs in a batch have different shapes

                    temp = cv2.resize(image,(image_width,image_height))
                    temp = temp/255 #Normalize data

                    batch_data[folder,idx,:,:,0] = (temp[:,:,0])  #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (temp[:,:,1])  #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (temp[:,:,2])  #normalise and feed in the image

                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do


        # write the code for the remaining data points which are left after full batches
        if (len(folder_list) != batch_size*num_batches):
            print("Batch: ",num_batches+1,"Index:", batch_size)
            batch_size = len(folder_list) - (batch_size*num_batches)
            batch_data = np.zeros((batch_size,image_count,image_width,image_height,channels)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,num_classes)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                    #crop the images and resize them. Note that the images are of 2 different shape
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    temp = cv2.resize(image,(image_width,image_height))
                    temp = temp/255 #Normalize data

                    batch_data[folder,idx,:,:,0] = (temp[:,:,0])
                    batch_data[folder,idx,:,:,1] = (temp[:,:,1])
                    batch_data[folder,idx,:,:,2] = (temp[:,:,2])

                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels

# %%
train_doc = np.random.permutation(open(f'Gesture_Recognition/Project_data/train.csv').readlines())
val_doc = np.random.permutation(open(f'Gesture_Recognition/Project_data/val.csv').readlines())

batch_size = 10 #experiment with the batch size
image_count = 30 # number of images to be used for each video
image_height=160
image_width=160
channels=3
num_classes=5 # number of classes
input_shape=(image_count,image_width,image_height,channels)
curr_dt_time = datetime.datetime.now()
train_path = f'Gesture_Recognition/Project_data/train'
val_path = f'Gesture_Recognition/Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 30 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 30

# %%
from keras.applications import ResNet152V2
# EfficientNetB7 with rnn gru units
model = Sequential()
model.add(TimeDistributed(ResNet152V2(weights='imagenet', include_top=False),input_shape=input_shape, name='ResNet152V2', trainable=False))
model.add(TimeDistributed(GlobalAveragePooling2D()))
model.add(TimeDistributed(Dense(64, activation='relu')))
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(GRU(128, return_sequences=True))
model.add(BatchNormalization())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234545216/234545216 [==============================] - 1s 0us/step

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
optimiser = optimizers.Adam() #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  ResNet152V2 (TimeDistribut  (None, 30, 5, 5, 2048)    58331648
#  ed)
#
#  time_distributed (TimeDist  (None, 30, 2048)          0
#  ributed)
#
#  time_distributed_1 (TimeDi  (None, 30, 64)            131136
#  stributed)
#
#  dense_1 (Dense)             (None, 30, 256)           16640
#
#  batch_normalization (Batch  (None, 30, 256)           1024
#  Normalization)
#
#  gru (GRU)                   (None, 30, 128)           148224
#
#  batch_normalization_1 (Bat  (None, 30, 128)           512
#  chNormalization)
#
#  flatten (Flatten)           (None, 3840)              0
#
#  dense_2 (Dense)             (None, 256)               983296
#
#  dense_3 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 59613765 (227.41 MB)
# Trainable params: 1281349 (4.89 MB)
# Non-trainable params: 58332416 (222.52 MB)
# _________________________________________________________________
# None

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %%
curr_dt_time = datetime.datetime.now()
model_name = 'model_init_exp_16' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'

if not os.path.exists(model_name):
    os.mkdir(model_name)

filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001, verbose=1) # write the REducelronplateau code here

callbacks_list = [checkpoint, LR]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history=model.fit(train_generator,
                  steps_per_epoch=steps_per_epoch,
                  epochs=num_epochs,
                  verbose=1,
                  callbacks=callbacks_list,
                  validation_data=val_generator,
                  validation_steps=validation_steps,
                  class_weight=None,
                  workers=1,
                  initial_epoch=0,
                  max_queue_size=3000)
# Out:
# Source path =  Gesture_Recognition/Project_data/train ; batch size = 10
# Epoch 1/30
# 64/67 [===========================>..] - ETA: 7s - loss: 2.9354 - categorical_accuracy: 0.4031Batch:  67 Index: 10
# 67/67 [==============================] - ETA: 0s - loss: 2.9264 - categorical_accuracy: 0.4012Source path =  Gesture_Recognition/Project_data/val ; batch size = 10
#
# Epoch 1: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00001-2.92640-0.40121-3.12334-0.42000.h5
# 67/67 [==============================] - 226s 3s/step - loss: 2.9264 - categorical_accuracy: 0.4012 - val_loss: 3.1233 - val_categorical_accuracy: 0.4200 - lr: 0.0010
# Epoch 2/30
# 67/67 [==============================] - ETA: 0s - loss: 3.7859 - categorical_accuracy: 0.4478
# Epoch 2: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00002-3.78587-0.44776-5.82682-0.39000.h5
# 67/67 [==============================] - 79s 1s/step - loss: 3.7859 - categorical_accuracy: 0.4478 - val_loss: 5.8268 - val_categorical_accuracy: 0.3900 - lr: 0.0010
# Epoch 3/30
# 67/67 [==============================] - ETA: 0s - loss: 4.9215 - categorical_accuracy: 0.4179
# Epoch 3: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00003-4.92150-0.41791-16.82948-0.33000.h5
# 67/67 [==============================] - 69s 1s/step - loss: 4.9215 - categorical_accuracy: 0.4179 - val_loss: 16.8295 - val_categorical_accuracy: 0.3300 - lr: 0.0010
# Epoch 4/30
# 67/67 [==============================] - ETA: 0s - loss: 4.1357 - categorical_accuracy: 0.3781
# Epoch 4: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00004-4.13572-0.37811-8.30761-0.32000.h5
# 67/67 [==============================] - 77s 1s/step - loss: 4.1357 - categorical_accuracy: 0.3781 - val_loss: 8.3076 - val_categorical_accuracy: 0.3200 - lr: 0.0010
# Epoch 5/30
# 67/67 [==============================] - ETA: 0s - loss: 2.4308 - categorical_accuracy: 0.5423
# Epoch 5: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00005-2.43081-0.54229-4.10846-0.46000.h5
# 67/67 [==============================] - 75s 1s/step - loss: 2.4308 - categorical_accuracy: 0.5423 - val_loss: 4.1085 - val_categorical_accuracy: 0.4600 - lr: 0.0010
# Epoch 6/30
# 67/67 [==============================] - ETA: 0s - loss: 1.7831 - categorical_accuracy: 0.5771
# Epoch 6: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00006-1.78312-0.57711-4.59678-0.37000.h5
# 67/67 [==============================] - 75s 1s/step - loss: 1.7831 - categorical_accuracy: 0.5771 - val_loss: 4.5968 - val_categorical_accuracy: 0.3700 - lr: 0.0010
# Epoch 7/30
# 67/67 [==============================] - ETA: 0s - loss: 1.9805 - categorical_accuracy: 0.5025
# Epoch 7: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00007-1.98051-0.50249-2.93810-0.51000.h5
# 67/67 [==============================] - 79s 1s/step - loss: 1.9805 - categorical_accuracy: 0.5025 - val_loss: 2.9381 - val_categorical_accuracy: 0.5100 - lr: 0.0010
# Epoch 8/30
# 67/67 [==============================] - ETA: 0s - loss: 1.5467 - categorical_accuracy: 0.5473
# Epoch 8: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00008-1.54674-0.54726-2.90666-0.58000.h5
# 67/67 [==============================] - 77s 1s/step - loss: 1.5467 - categorical_accuracy: 0.5473 - val_loss: 2.9067 - val_categorical_accuracy: 0.5800 - lr: 0.0010
# Epoch 9/30
# 67/67 [==============================] - ETA: 0s - loss: 1.3984 - categorical_accuracy: 0.5970
# Epoch 9: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00009-1.39843-0.59701-2.93457-0.48000.h5
# 67/67 [==============================] - 73s 1s/step - loss: 1.3984 - categorical_accuracy: 0.5970 - val_loss: 2.9346 - val_categorical_accuracy: 0.4800 - lr: 0.0010
# Epoch 10/30
# 67/67 [==============================] - ETA: 0s - loss: 1.1744 - categorical_accuracy: 0.5970
# Epoch 10: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00010-1.17443-0.59701-3.25389-0.51000.h5
# 67/67 [==============================] - 77s 1s/step - loss: 1.1744 - categorical_accuracy: 0.5970 - val_loss: 3.2539 - val_categorical_accuracy: 0.5100 - lr: 0.0010
# Epoch 11/30
# 67/67 [==============================] - ETA: 0s - loss: 1.1271 - categorical_accuracy: 0.5970
# Epoch 11: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00011-1.12712-0.59701-2.03955-0.55000.h5
# 67/67 [==============================] - 73s 1s/step - loss: 1.1271 - categorical_accuracy: 0.5970 - val_loss: 2.0396 - val_categorical_accuracy: 0.5500 - lr: 0.0010
# Epoch 12/30
# 67/67 [==============================] - ETA: 0s - loss: 1.0132 - categorical_accuracy: 0.6368
# Epoch 12: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00012-1.01316-0.63682-2.01335-0.49000.h5
# 67/67 [==============================] - 72s 1s/step - loss: 1.0132 - categorical_accuracy: 0.6368 - val_loss: 2.0133 - val_categorical_accuracy: 0.4900 - lr: 0.0010
# Epoch 13/30
# 67/67 [==============================] - ETA: 0s - loss: 0.8325 - categorical_accuracy: 0.7065
# Epoch 13: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00013-0.83252-0.70647-2.71657-0.57000.h5
# 67/67 [==============================] - 79s 1s/step - loss: 0.8325 - categorical_accuracy: 0.7065 - val_loss: 2.7166 - val_categorical_accuracy: 0.5700 - lr: 0.0010
# Epoch 14/30
# 67/67 [==============================] - ETA: 0s - loss: 0.8558 - categorical_accuracy: 0.6517
# Epoch 14: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00014-0.85581-0.65174-1.92219-0.60000.h5
# 67/67 [==============================] - 69s 1s/step - loss: 0.8558 - categorical_accuracy: 0.6517 - val_loss: 1.9222 - val_categorical_accuracy: 0.6000 - lr: 0.0010
# Epoch 15/30
# 67/67 [==============================] - ETA: 0s - loss: 0.8832 - categorical_accuracy: 0.7015
# Epoch 15: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00015-0.88320-0.70149-1.98281-0.54000.h5
# 67/67 [==============================] - 74s 1s/step - loss: 0.8832 - categorical_accuracy: 0.7015 - val_loss: 1.9828 - val_categorical_accuracy: 0.5400 - lr: 0.0010
# Epoch 16/30
# 67/67 [==============================] - ETA: 0s - loss: 0.7242 - categorical_accuracy: 0.7512
# Epoch 16: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00016-0.72415-0.75124-1.82626-0.56000.h5
# 67/67 [==============================] - 77s 1s/step - loss: 0.7242 - categorical_accuracy: 0.7512 - val_loss: 1.8263 - val_categorical_accuracy: 0.5600 - lr: 0.0010
# Epoch 17/30
# 67/67 [==============================] - ETA: 0s - loss: 0.7037 - categorical_accuracy: 0.7264
# Epoch 17: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00017-0.70371-0.72637-1.74595-0.62000.h5
# 67/67 [==============================] - 79s 1s/step - loss: 0.7037 - categorical_accuracy: 0.7264 - val_loss: 1.7460 - val_categorical_accuracy: 0.6200 - lr: 0.0010
# Epoch 18/30
# 67/67 [==============================] - ETA: 0s - loss: 0.4721 - categorical_accuracy: 0.8358
# Epoch 18: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00018-0.47210-0.83582-1.19893-0.68000.h5
# 67/67 [==============================] - 71s 1s/step - loss: 0.4721 - categorical_accuracy: 0.8358 - val_loss: 1.1989 - val_categorical_accuracy: 0.6800 - lr: 0.0010
# Epoch 19/30
# 67/67 [==============================] - ETA: 0s - loss: 0.5723 - categorical_accuracy: 0.8010
# Epoch 19: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00019-0.57228-0.80100-1.72967-0.68000.h5
# 67/67 [==============================] - 74s 1s/step - loss: 0.5723 - categorical_accuracy: 0.8010 - val_loss: 1.7297 - val_categorical_accuracy: 0.6800 - lr: 0.0010
# Epoch 20/30
# 67/67 [==============================] - ETA: 0s - loss: 0.6503 - categorical_accuracy: 0.7811
# Epoch 20: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00020-0.65031-0.78109-2.22267-0.68000.h5
# 67/67 [==============================] - 80s 1s/step - loss: 0.6503 - categorical_accuracy: 0.7811 - val_loss: 2.2227 - val_categorical_accuracy: 0.6800 - lr: 0.0010
# Epoch 21/30
# 67/67 [==============================] - ETA: 0s - loss: 0.5983 - categorical_accuracy: 0.7463
# Epoch 21: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00021-0.59826-0.74627-2.16775-0.65000.h5
# 67/67 [==============================] - 73s 1s/step - loss: 0.5983 - categorical_accuracy: 0.7463 - val_loss: 2.1678 - val_categorical_accuracy: 0.6500 - lr: 0.0010
# Epoch 22/30
# 67/67 [==============================] - ETA: 0s - loss: 0.7989 - categorical_accuracy: 0.7463
# Epoch 22: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00022-0.79887-0.74627-2.35089-0.60000.h5
# 67/67 [==============================] - 74s 1s/step - loss: 0.7989 - categorical_accuracy: 0.7463 - val_loss: 2.3509 - val_categorical_accuracy: 0.6000 - lr: 0.0010
# Epoch 23/30
# 67/67 [==============================] - ETA: 0s - loss: 0.8546 - categorical_accuracy: 0.7164
# Epoch 23: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00023-0.85463-0.71642-1.36732-0.63000.h5
# 67/67 [==============================] - 80s 1s/step - loss: 0.8546 - categorical_accuracy: 0.7164 - val_loss: 1.3673 - val_categorical_accuracy: 0.6300 - lr: 0.0010
# Epoch 24/30
# 67/67 [==============================] - ETA: 0s - loss: 0.5816 - categorical_accuracy: 0.7910
# Epoch 24: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00024-0.58158-0.79104-2.32280-0.64000.h5
# 67/67 [==============================] - 72s 1s/step - loss: 0.5816 - categorical_accuracy: 0.7910 - val_loss: 2.3228 - val_categorical_accuracy: 0.6400 - lr: 0.0010
# Epoch 25/30
# 67/67 [==============================] - ETA: 0s - loss: 0.5202 - categorical_accuracy: 0.8159
# Epoch 25: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00025-0.52023-0.81592-4.30108-0.59000.h5
# 67/67 [==============================] - 79s 1s/step - loss: 0.5202 - categorical_accuracy: 0.8159 - val_loss: 4.3011 - val_categorical_accuracy: 0.5900 - lr: 0.0010
# Epoch 26/30
# 67/67 [==============================] - ETA: 0s - loss: 0.7219 - categorical_accuracy: 0.7612
# Epoch 26: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00026-0.72187-0.76119-2.82436-0.54000.h5
# 67/67 [==============================] - 73s 1s/step - loss: 0.7219 - categorical_accuracy: 0.7612 - val_loss: 2.8244 - val_categorical_accuracy: 0.5400 - lr: 0.0010
# Epoch 27/30
# 67/67 [==============================] - ETA: 0s - loss: 0.6995 - categorical_accuracy: 0.7761
# Epoch 27: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00027-0.69948-0.77612-1.48487-0.64000.h5
# 67/67 [==============================] - 75s 1s/step - loss: 0.6995 - categorical_accuracy: 0.7761 - val_loss: 1.4849 - val_categorical_accuracy: 0.6400 - lr: 0.0010
# Epoch 28/30
# 67/67 [==============================] - ETA: 0s - loss: 0.4396 - categorical_accuracy: 0.8358
# Epoch 28: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00028-0.43964-0.83582-1.95299-0.61000.h5
# 67/67 [==============================] - 70s 1s/step - loss: 0.4396 - categorical_accuracy: 0.8358 - val_loss: 1.9530 - val_categorical_accuracy: 0.6100 - lr: 0.0010
# Epoch 29/30
# 67/67 [==============================] - ETA: 0s - loss: 0.5158 - categorical_accuracy: 0.8358
# Epoch 29: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00029-0.51577-0.83582-1.58802-0.58000.h5
# 67/67 [==============================] - 68s 1s/step - loss: 0.5158 - categorical_accuracy: 0.8358 - val_loss: 1.5880 - val_categorical_accuracy: 0.5800 - lr: 0.0010
# Epoch 30/30
# 67/67 [==============================] - ETA: 0s - loss: 0.4849 - categorical_accuracy: 0.8259
# Epoch 30: saving model to model_init_exp_16_2024-04-0908_47_53.910098/model-00030-0.48494-0.82587-1.62022-0.55000.h5
# 67/67 [==============================] - 73s 1s/step - loss: 0.4849 - categorical_accuracy: 0.8259 - val_loss: 1.6202 - val_categorical_accuracy: 0.5500 - lr: 0.0010

# %%
plt.figure(figsize=(20,6))
ax1 = plt.subplot(121)
ax1 = plt.plot(history.history['loss'])
ax1 = plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
ax2 = plt.subplot(122)
ax2 = plt.plot(history.history['categorical_accuracy'])
ax2 = plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('categorical_accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
