# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
# !git clone https://github.com/Gurupreet1111/Gesture_Recognition.git
# Out:
# Cloning into 'Gesture_Recognition'...
# remote: Enumerating objects: 23552, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 23552 (delta 10), reused 9 (delta 1), pack-reused 23526
# Receiving objects: 100% (23552/23552), 1.58 GiB | 40.57 MiB/s, done.
# Resolving deltas: 100% (11/11), done.
# Updating files: 100% (22895/22895), done.

# %%
import numpy as np
import os
#from scipy.misc.pilutil import imread, imresize
import cv2

from imageio.v2 import imread

import datetime
import os
from PIL import Image, ImageFilter, ImageEnhance
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
import os
os.environ['PYTHONHASHSEED']="30"
np.random.seed(30)
import random as rn
rn.seed(30)
import tensorflow as tf
tf.random.set_seed(30)
from keras import backend as K

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
# train and validatiaon data creator with ablation
# when ablation is 10, then 10 folders for each label will be selected.
def get_data(path, ablation=None):
    train_doc = np.random.permutation(open(path+'train.csv').readlines())
    val_doc = np.random.permutation(open(path+'val.csv').readlines())
    counts = np.zeros(5) # count for loading folders for 5 classes
    train_data = []
    val_data = []
    # when ablation is None pass full training and val data
    if ablation is not None:
        # iterating train doc
        for doc in train_doc:
            lable = int(doc.strip().split(';')[2])
            if counts[lable] < ablation:
                train_data.append(doc)
                counts[lable] += 1
        counts = np.zeros(5)
        # iterating val doc
        for doc in val_doc:
            lable = int(doc.strip().split(';')[2])
            if counts[lable] < ablation:
                val_data.append(doc)
                counts[lable] += 1
    else:
        train_data, val_data = train_doc, val_doc
    return train_data, val_data

# %%
train_doc, val_doc = get_data('Gesture_Recognition/Project_data/', ablation=None)
batch_size = 32 # experiment with the batch size
enable_augmentation = False # augmentation of Data
# sequence ids
# selecting alternate frames from 7 to 26.
seq_idx = range(7,26,2)
# image dimensions
dim_x, dim_y = 120, 120

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
# generator with augmentation for train data
def generator(source_path, folder_list, batch_size, is_train = False, augmention = False, debug=False):
    # print('\nSource path = ', source_path, '; batch size =', batch_size)
    img_idx = seq_idx #create a list of image numbers you want to use for a particular video
    x = len(img_idx)
    y, z = dim_x, dim_y
    while True:
        # doubling the data for augmentation
        if is_train and augmention:
            t = np.concatenate((np.random.permutation(folder_list), np.random.permutation(folder_list)))
        else:
            t = np.random.permutation(folder_list)

        if (len(t)%batch_size) == 0:
            num_batches = int(len(t)/batch_size)
        else:
            num_batches = len(t)//batch_size + 1

        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                if debug:
                    plt.figure(figsize=(20,5))
                #handling remaining datapoints
                folder_idx = folder + (batch*batch_size)
                if folder_idx >= len(t):
                    break
                folder_str = t[folder_idx]
                imgs = os.listdir(source_path+'/'+ folder_str.split(';')[0]) # read all the images in the folder
                # randomly enabling augmentation and augmentation type
                aug_type = None
                if is_train and augmention and rn.randint(0,1) == 1:
                    aug_type = rn.randint(0, 4) #randomly selecting augmentation type
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ folder_str.strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                    # plotting original images for debugging purpose only
                    if debug:
                        plt.subplot(2, x, idx+1)
                        plt.imshow(image.astype('uint8'))

                    #crop the images and resize them. Note that the images are of 2 different shape
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    # making the rectangle images into square by cropping sides
                    # so the aspect ration can be mantained while resizing.
                    if image.shape[1] > image.shape[0]:
                        diff_px = image.shape[1] - image.shape[0]
                        crop_start = diff_px//2
                        crop_end = crop_start + image.shape[0]
                        image = image[:, crop_start:crop_end]
                    elif image.shape[0] > image.shape[1]:
                        diff_px = image.shape[0] - image.shape[1]
                        crop_start = diff_px//2
                        crop_end = crop_start + image.shape[1]
                        image = image[:, crop_start:crop_end]
                    resized_im = cv2.resize(image, (y,z))

                    if aug_type is not None:
                        if aug_type == 0: # edge Enhancement
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.EDGE_ENHANCE))
                        elif aug_type == 1: # adding gaussian blur
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.GaussianBlur(1)))
                        elif aug_type == 2: # enchancing image detailing
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.DETAIL))
                        elif aug_type == 3: # sharpening image
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.SHARPEN))
                        elif aug_type == 4: # Brightness enhancement
                            resized_im = np.array(ImageEnhance.Brightness((Image.fromarray(resized_im, 'RGB'))).enhance(1.5))
                    # plotting rezised images for debugging purpose only
                    if debug:
                        plt.subplot(2, x, idx+x+1)
                        plt.imshow(resized_im)

                    batch_data[folder,idx,:,:,0] = resized_im[:,:,0]/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = resized_im[:,:,1]/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = resized_im[:,:,2]/255 #normalise and feed in the image

                batch_labels[folder, int(folder_str.strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = 'Gesture_Recognition/Project_data/train'
val_path =  'Gesture_Recognition/Project_data/val'

#multiply number train seq by 2 when using augmentation
multiplier = 1
if enable_augmentation:
    multiplier = 2
num_train_sequences = len(train_doc)*multiplier
print('# training sequences =', num_train_sequences)

num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)

num_epochs = 50 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 50

# %%
# testing generative
test_gen = generator(train_path, train_doc, 1, is_train = True, augmention = True, debug = True)
d = next(test_gen)[0]

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Bidirectional, BatchNormalization, Activation, Dropout, GlobalAveragePooling2D, GlobalAveragePooling3D, ConvLSTM2D
from keras.layers import Conv2D, Conv3D, MaxPooling2D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers

#input shape for the st layer
input_shape = (len(seq_idx), dim_x, dim_y, 3)
np.random.seed(30)

# %% [markdown]
# ### Experiment - 1 & 2
# **Conv3D**

# %%
model1 = Sequential()
model1.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
model1.add(MaxPooling3D(pool_size=2))

model1.add(Conv3D(64, kernel_size=3, activation='relu'))
model1.add(MaxPooling3D(pool_size=2))

model1.add(Flatten())
model1.add(Dense(256, activation='relu'))
model1.add(Dense(5, activation='softmax'))

optimiser = optimizers.Adam(lr=0.01) #write your optimizer
model1.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model1.summary())

history = model1.fit_generator(train_generator,
                               steps_per_epoch=steps_per_epoch,
                               epochs=20,
                               verbose=1,
                                callbacks=callbacks_list,
                               validation_data=val_generator,
                        validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)

# %% [markdown]
# ### Experiment - 3
# **Conv3D**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Conv3D(256, kernel_size=(3, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(3, 2, 2)))

# model.add(Conv3D(512, kernel_size=(3, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(3, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 4
# **Conv3D**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))

# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 5 & 6
# **Conv3D**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())

# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 7 & 8
# **Conv3D**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())
# #model.add(Dropout(0.2))
# model.add(Dropout(0.5))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# #model.add(Dropout(0.2))
# model.add(Dropout(0.5))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# #model.add(Dropout(0.2))
# model.add(Dropout(0.5))

# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# #model.add(Dropout(0.2))
# model.add(Dropout(0.5))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 9
# **Conv3D**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 10
# **Conv3D**

# %%
# loss: 0.1388 - categorical_accuracy: 0.9539 - val_loss: 0.1661 - val_categorical_accuracy: 0.9297
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(GlobalAveragePooling3D())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 11
# **TimeDistributed Conv2D + GRU**

# %%
# model = Sequential()
# model.add(TimeDistributed(
#     Conv2D(32, (3,3), activation='relu'), input_shape=input_shape)
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())

# model.add(TimeDistributed(
#     Conv2D(64, (3,3), activation='relu'))
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())

# model.add(TimeDistributed(GlobalAveragePooling2D()))
# model.add(TimeDistributed(Dense(64, activation='relu')))
# model.add(BatchNormalization())

# model.add(GRU(128))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 12
# **TimeDistributed Conv2D + GRU**

# %%
# model = Sequential()
# model.add(TimeDistributed(
#     Conv2D(32, (3,3), activation='relu'), input_shape=input_shape)
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(TimeDistributed(
#     Conv2D(64, (3,3), activation='relu'))
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(TimeDistributed(GlobalAveragePooling2D()))
# model.add(TimeDistributed(Dense(64, activation='relu')))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))

# model.add(GRU(128))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 13
# **TimeDistributed Conv2D + Dense**

# %%
# model = Sequential()
# model.add(TimeDistributed(
#     Conv2D(32, (3,3), activation='relu'), input_shape=input_shape)
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())

# model.add(TimeDistributed(
#     Conv2D(64, (3,3), activation='relu'))
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())

# model.add(TimeDistributed(
#     Conv2D(128, (3,3), activation='relu'))
# )
# model.add(TimeDistributed(
#     MaxPooling2D((2,2)))
# )
# model.add(BatchNormalization())

# model.add(GlobalAveragePooling3D())
# model.add(Dense(256, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 14
# **TimeDistributed + ConvLSTM2D**

# %%
# model = Sequential()
# model.add(TimeDistributed(
#     Conv2D(8, (3,3), activation='relu'), input_shape=input_shape)
# )
# model.add(BatchNormalization())
# model.add(TimeDistributed(
#     Conv2D(16, (3,3), activation='relu'))
# )
# model.add(BatchNormalization())
# model.add(
#     ConvLSTM2D(8, kernel_size = 3, return_sequences=False)
# )
# model.add(BatchNormalization())
# model.add(TimeDistributed(
#     Dense(64, activation='relu'))
# )
# model.add(BatchNormalization())
# model.add(GlobalAveragePooling2D())
# model.add(Dense(64, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# # Final Model

# %%
model = Sequential()
model.add(TimeDistributed(
    Conv2D(8, (3,3), activation='relu'), input_shape=input_shape)
)
model.add(BatchNormalization())
model.add(TimeDistributed(
    Conv2D(16, (3,3), activation='relu'))
)
model.add(BatchNormalization())
model.add(
    ConvLSTM2D(8, kernel_size = 3, return_sequences=False)
)
model.add(BatchNormalization())
model.add(TimeDistributed(
    Dense(64, activation='relu'))
)
model.add(BatchNormalization())
model.add(GlobalAveragePooling2D())
model.add(Dense(64, activation='relu'))
model.add(Dense(5, activation='softmax'))

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = optimizers.Adam(lr=0.01) #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model.summary())
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_2 (TimeDi  (None, 30, 158, 158, 8)   224
#  stributed)
#
#  batch_normalization_2 (Bat  (None, 30, 158, 158, 8)   32
#  chNormalization)
#
#  time_distributed_3 (TimeDi  (None, 30, 156, 156, 16   1168
#  stributed)                  )
#
#  batch_normalization_3 (Bat  (None, 30, 156, 156, 16   64
#  chNormalization)            )
#
#  conv_lstm2d (ConvLSTM2D)    (None, 154, 154, 8)       6944
#
#  batch_normalization_4 (Bat  (None, 154, 154, 8)       32
#  chNormalization)
#
#  time_distributed_4 (TimeDi  (None, 154, 154, 64)      576
#  stributed)
#
#  batch_normalization_5 (Bat  (None, 154, 154, 64)      256
#  chNormalization)
#
#  global_average_pooling2d_1  (None, 64)                0
#   (GlobalAveragePooling2D)
#
#  dense_5 (Dense)             (None, 64)                4160
#
#  dense_6 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 13781 (53.83 KB)
# Trainable params: 13589 (53.08 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________
# None

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size, is_train = True, augmention = enable_augmentation)
val_generator = generator(val_path, val_doc, batch_size)

# %%
curr_dt_time = datetime.datetime.now()
model_name = 'model_init_exp_16' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'

if not os.path.exists(model_name):
    os.mkdir(model_name)

filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001, verbose=1) # write the REducelronplateau code here

callbacks_list = [checkpoint, LR]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                        callbacks=callbacks_list, validation_data=val_generator,
                        validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/50
# 67/67 [==============================] - ETA: 0s - loss: 1.4140 - categorical_accuracy: 0.3493
# Epoch 1: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00001-1.41404-0.34925-1.62116-0.23000.h5
# 67/67 [==============================] - 37s 418ms/step - loss: 1.4140 - categorical_accuracy: 0.3493 - val_loss: 1.6212 - val_categorical_accuracy: 0.2300 - lr: 0.0010
# Epoch 2/50
# 67/67 [==============================] - ETA: 0s - loss: 1.2072 - categorical_accuracy: 0.4597
# Epoch 2: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00002-1.20722-0.45970-1.67273-0.17000.h5
# 67/67 [==============================] - 25s 378ms/step - loss: 1.2072 - categorical_accuracy: 0.4597 - val_loss: 1.6727 - val_categorical_accuracy: 0.1700 - lr: 0.0010
# Epoch 3/50
# 67/67 [==============================] - ETA: 0s - loss: 1.0754 - categorical_accuracy: 0.5299
# Epoch 3: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00003-1.07542-0.52985-1.88898-0.26000.h5
# 67/67 [==============================] - 26s 386ms/step - loss: 1.0754 - categorical_accuracy: 0.5299 - val_loss: 1.8890 - val_categorical_accuracy: 0.2600 - lr: 0.0010
# Epoch 4/50
# 67/67 [==============================] - ETA: 0s - loss: 1.0765 - categorical_accuracy: 0.5149
# Epoch 4: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00004-1.07649-0.51493-2.20840-0.25000.h5
# 67/67 [==============================] - 25s 372ms/step - loss: 1.0765 - categorical_accuracy: 0.5149 - val_loss: 2.2084 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 5/50
# 67/67 [==============================] - ETA: 0s - loss: 0.9823 - categorical_accuracy: 0.5836
# Epoch 5: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00005-0.98233-0.58358-1.67334-0.29000.h5
# 67/67 [==============================] - 25s 373ms/step - loss: 0.9823 - categorical_accuracy: 0.5836 - val_loss: 1.6733 - val_categorical_accuracy: 0.2900 - lr: 0.0010
# Epoch 6/50
# 67/67 [==============================] - ETA: 0s - loss: 0.9433 - categorical_accuracy: 0.6060
# Epoch 6: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00006-0.94330-0.60597-1.48563-0.34000.h5
# 67/67 [==============================] - 25s 374ms/step - loss: 0.9433 - categorical_accuracy: 0.6060 - val_loss: 1.4856 - val_categorical_accuracy: 0.3400 - lr: 0.0010
# Epoch 7/50
# 67/67 [==============================] - ETA: 0s - loss: 0.8828 - categorical_accuracy: 0.6433
# Epoch 7: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00007-0.88283-0.64328-0.97829-0.49000.h5
# 67/67 [==============================] - 25s 381ms/step - loss: 0.8828 - categorical_accuracy: 0.6433 - val_loss: 0.9783 - val_categorical_accuracy: 0.4900 - lr: 0.0010
# Epoch 8/50
# 67/67 [==============================] - ETA: 0s - loss: 0.8188 - categorical_accuracy: 0.6507
# Epoch 8: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00008-0.81878-0.65075-0.95678-0.61000.h5
# 67/67 [==============================] - 26s 382ms/step - loss: 0.8188 - categorical_accuracy: 0.6507 - val_loss: 0.9568 - val_categorical_accuracy: 0.6100 - lr: 0.0010
# Epoch 9/50
# 67/67 [==============================] - ETA: 0s - loss: 0.7906 - categorical_accuracy: 0.6821
# Epoch 9: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00009-0.79059-0.68209-1.35282-0.51000.h5
# 67/67 [==============================] - 26s 393ms/step - loss: 0.7906 - categorical_accuracy: 0.6821 - val_loss: 1.3528 - val_categorical_accuracy: 0.5100 - lr: 0.0010
# Epoch 10/50
# 67/67 [==============================] - ETA: 0s - loss: 0.7771 - categorical_accuracy: 0.6985
# Epoch 10: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00010-0.77711-0.69851-0.98229-0.61000.h5
# 67/67 [==============================] - 25s 380ms/step - loss: 0.7771 - categorical_accuracy: 0.6985 - val_loss: 0.9823 - val_categorical_accuracy: 0.6100 - lr: 0.0010
# Epoch 11/50
# 67/67 [==============================] - ETA: 0s - loss: 0.7523 - categorical_accuracy: 0.7134
# Epoch 11: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00011-0.75230-0.71343-0.75146-0.72000.h5
# 67/67 [==============================] - 26s 390ms/step - loss: 0.7523 - categorical_accuracy: 0.7134 - val_loss: 0.7515 - val_categorical_accuracy: 0.7200 - lr: 0.0010
# Epoch 12/50
# 67/67 [==============================] - ETA: 0s - loss: 0.7237 - categorical_accuracy: 0.7075
# Epoch 12: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00012-0.72369-0.70746-1.08335-0.62000.h5
# 67/67 [==============================] - 26s 386ms/step - loss: 0.7237 - categorical_accuracy: 0.7075 - val_loss: 1.0833 - val_categorical_accuracy: 0.6200 - lr: 0.0010
# Epoch 13/50
# 67/67 [==============================] - ETA: 0s - loss: 0.6728 - categorical_accuracy: 0.7269
# Epoch 13: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00013-0.67278-0.72687-0.68831-0.75000.h5
# 67/67 [==============================] - 26s 389ms/step - loss: 0.6728 - categorical_accuracy: 0.7269 - val_loss: 0.6883 - val_categorical_accuracy: 0.7500 - lr: 0.0010
# Epoch 14/50
# 67/67 [==============================] - ETA: 0s - loss: 0.6494 - categorical_accuracy: 0.7358
# Epoch 14: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00014-0.64941-0.73582-0.62698-0.79000.h5
# 67/67 [==============================] - 24s 367ms/step - loss: 0.6494 - categorical_accuracy: 0.7358 - val_loss: 0.6270 - val_categorical_accuracy: 0.7900 - lr: 0.0010
# Epoch 15/50
# 67/67 [==============================] - ETA: 0s - loss: 0.6492 - categorical_accuracy: 0.7403
# Epoch 15: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00015-0.64922-0.74030-1.06351-0.55000.h5
# 67/67 [==============================] - 25s 368ms/step - loss: 0.6492 - categorical_accuracy: 0.7403 - val_loss: 1.0635 - val_categorical_accuracy: 0.5500 - lr: 0.0010
# Epoch 16/50
# 67/67 [==============================] - ETA: 0s - loss: 0.6577 - categorical_accuracy: 0.7388
# Epoch 16: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00016-0.65772-0.73881-0.58331-0.78000.h5
# 67/67 [==============================] - 26s 389ms/step - loss: 0.6577 - categorical_accuracy: 0.7388 - val_loss: 0.5833 - val_categorical_accuracy: 0.7800 - lr: 0.0010
# Epoch 17/50
# 67/67 [==============================] - ETA: 0s - loss: 0.6757 - categorical_accuracy: 0.7239
# Epoch 17: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00017-0.67573-0.72388-1.04263-0.62000.h5
# 67/67 [==============================] - 26s 392ms/step - loss: 0.6757 - categorical_accuracy: 0.7239 - val_loss: 1.0426 - val_categorical_accuracy: 0.6200 - lr: 0.0010
# Epoch 18/50
# 67/67 [==============================] - ETA: 0s - loss: 0.5788 - categorical_accuracy: 0.7627
# Epoch 18: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00018-0.57878-0.76269-0.90143-0.62000.h5
# 67/67 [==============================] - 25s 375ms/step - loss: 0.5788 - categorical_accuracy: 0.7627 - val_loss: 0.9014 - val_categorical_accuracy: 0.6200 - lr: 0.0010
# Epoch 19/50
# 67/67 [==============================] - ETA: 0s - loss: 0.6121 - categorical_accuracy: 0.7493
# Epoch 19: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00019-0.61206-0.74925-0.71472-0.77000.h5
# 67/67 [==============================] - 25s 372ms/step - loss: 0.6121 - categorical_accuracy: 0.7493 - val_loss: 0.7147 - val_categorical_accuracy: 0.7700 - lr: 0.0010
# Epoch 20/50
# 67/67 [==============================] - ETA: 0s - loss: 0.5765 - categorical_accuracy: 0.7597
# Epoch 20: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00020-0.57647-0.75970-0.72976-0.72000.h5
# 67/67 [==============================] - 27s 405ms/step - loss: 0.5765 - categorical_accuracy: 0.7597 - val_loss: 0.7298 - val_categorical_accuracy: 0.7200 - lr: 0.0010
# Epoch 21/50
# 67/67 [==============================] - ETA: 0s - loss: 0.5649 - categorical_accuracy: 0.7448
# Epoch 21: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00021-0.56485-0.74478-0.84052-0.67000.h5
# 67/67 [==============================] - 25s 377ms/step - loss: 0.5649 - categorical_accuracy: 0.7448 - val_loss: 0.8405 - val_categorical_accuracy: 0.6700 - lr: 0.0010
# Epoch 22/50
# 67/67 [==============================] - ETA: 0s - loss: 0.5623 - categorical_accuracy: 0.7791
# Epoch 22: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00022-0.56228-0.77910-1.03769-0.66000.h5
# 67/67 [==============================] - 25s 383ms/step - loss: 0.5623 - categorical_accuracy: 0.7791 - val_loss: 1.0377 - val_categorical_accuracy: 0.6600 - lr: 0.0010
# Epoch 23/50
# 67/67 [==============================] - ETA: 0s - loss: 0.5444 - categorical_accuracy: 0.7701
# Epoch 23: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00023-0.54435-0.77015-0.83575-0.76000.h5
# 67/67 [==============================] - 26s 384ms/step - loss: 0.5444 - categorical_accuracy: 0.7701 - val_loss: 0.8358 - val_categorical_accuracy: 0.7600 - lr: 0.0010
# Epoch 24/50
# 67/67 [==============================] - ETA: 0s - loss: 0.5375 - categorical_accuracy: 0.7910
# Epoch 24: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00024-0.53747-0.79104-0.88685-0.68000.h5
# 67/67 [==============================] - 31s 465ms/step - loss: 0.5375 - categorical_accuracy: 0.7910 - val_loss: 0.8869 - val_categorical_accuracy: 0.6800 - lr: 0.0010
# Epoch 25/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4796 - categorical_accuracy: 0.7925
# Epoch 25: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00025-0.47956-0.79254-0.75348-0.74000.h5
# 67/67 [==============================] - 26s 395ms/step - loss: 0.4796 - categorical_accuracy: 0.7925 - val_loss: 0.7535 - val_categorical_accuracy: 0.7400 - lr: 0.0010
# Epoch 26/50
# 67/67 [==============================] - ETA: 0s - loss: 0.5162 - categorical_accuracy: 0.8075
# Epoch 26: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00026-0.51619-0.80746-0.79860-0.74000.h5
# 67/67 [==============================] - 27s 402ms/step - loss: 0.5162 - categorical_accuracy: 0.8075 - val_loss: 0.7986 - val_categorical_accuracy: 0.7400 - lr: 0.0010
# Epoch 27/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4730 - categorical_accuracy: 0.7925
# Epoch 27: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00027-0.47299-0.79254-1.19215-0.57000.h5
# 67/67 [==============================] - 25s 377ms/step - loss: 0.4730 - categorical_accuracy: 0.7925 - val_loss: 1.1921 - val_categorical_accuracy: 0.5700 - lr: 0.0010
# Epoch 28/50
# 67/67 [==============================] - ETA: 0s - loss: 0.5243 - categorical_accuracy: 0.8045
# Epoch 28: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00028-0.52430-0.80448-0.45824-0.83000.h5
# 67/67 [==============================] - 24s 367ms/step - loss: 0.5243 - categorical_accuracy: 0.8045 - val_loss: 0.4582 - val_categorical_accuracy: 0.8300 - lr: 0.0010
# Epoch 29/50
# 67/67 [==============================] - ETA: 0s - loss: 0.5687 - categorical_accuracy: 0.7552
# Epoch 29: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00029-0.56871-0.75522-0.92972-0.74000.h5
# 67/67 [==============================] - 25s 381ms/step - loss: 0.5687 - categorical_accuracy: 0.7552 - val_loss: 0.9297 - val_categorical_accuracy: 0.7400 - lr: 0.0010
# Epoch 30/50
# 67/67 [==============================] - ETA: 0s - loss: 0.5353 - categorical_accuracy: 0.7806
# Epoch 30: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00030-0.53533-0.78060-1.11069-0.62000.h5
# 67/67 [==============================] - 25s 370ms/step - loss: 0.5353 - categorical_accuracy: 0.7806 - val_loss: 1.1107 - val_categorical_accuracy: 0.6200 - lr: 0.0010
# Epoch 31/50
# 67/67 [==============================] - ETA: 0s - loss: 0.5151 - categorical_accuracy: 0.7970
# Epoch 31: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00031-0.51511-0.79701-0.68328-0.72000.h5
# 67/67 [==============================] - 26s 386ms/step - loss: 0.5151 - categorical_accuracy: 0.7970 - val_loss: 0.6833 - val_categorical_accuracy: 0.7200 - lr: 0.0010
# Epoch 32/50
# 67/67 [==============================] - ETA: 0s - loss: 0.5559 - categorical_accuracy: 0.7836
# Epoch 32: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00032-0.55589-0.78358-0.75098-0.73000.h5
# 67/67 [==============================] - 25s 368ms/step - loss: 0.5559 - categorical_accuracy: 0.7836 - val_loss: 0.7510 - val_categorical_accuracy: 0.7300 - lr: 0.0010
# Epoch 33/50
# 67/67 [==============================] - ETA: 0s - loss: 0.5886 - categorical_accuracy: 0.7701
# Epoch 33: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00033-0.58865-0.77015-0.72085-0.75000.h5
# 67/67 [==============================] - 25s 368ms/step - loss: 0.5886 - categorical_accuracy: 0.7701 - val_loss: 0.7209 - val_categorical_accuracy: 0.7500 - lr: 0.0010
# Epoch 34/50
# 67/67 [==============================] - ETA: 0s - loss: 0.5510 - categorical_accuracy: 0.7821
# Epoch 34: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00034-0.55102-0.78209-0.65558-0.75000.h5
# 67/67 [==============================] - 24s 362ms/step - loss: 0.5510 - categorical_accuracy: 0.7821 - val_loss: 0.6556 - val_categorical_accuracy: 0.7500 - lr: 0.0010
# Epoch 35/50
# 67/67 [==============================] - ETA: 0s - loss: 0.5560 - categorical_accuracy: 0.7761
# Epoch 35: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00035-0.55602-0.77612-0.61461-0.77000.h5
# 67/67 [==============================] - 26s 392ms/step - loss: 0.5560 - categorical_accuracy: 0.7761 - val_loss: 0.6146 - val_categorical_accuracy: 0.7700 - lr: 0.0010
# Epoch 36/50
# 67/67 [==============================] - ETA: 0s - loss: 0.5167 - categorical_accuracy: 0.8075
# Epoch 36: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00036-0.51671-0.80746-1.18901-0.59000.h5
# 67/67 [==============================] - 25s 376ms/step - loss: 0.5167 - categorical_accuracy: 0.8075 - val_loss: 1.1890 - val_categorical_accuracy: 0.5900 - lr: 0.0010
# Epoch 37/50
# 67/67 [==============================] - ETA: 0s - loss: 0.5258 - categorical_accuracy: 0.7985
# Epoch 37: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00037-0.52577-0.79851-0.55250-0.78000.h5
# 67/67 [==============================] - 24s 365ms/step - loss: 0.5258 - categorical_accuracy: 0.7985 - val_loss: 0.5525 - val_categorical_accuracy: 0.7800 - lr: 0.0010
# Epoch 38/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4622 - categorical_accuracy: 0.7866
# Epoch 38: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00038-0.46225-0.78657-0.81080-0.73000.h5
# 67/67 [==============================] - 25s 375ms/step - loss: 0.4622 - categorical_accuracy: 0.7866 - val_loss: 0.8108 - val_categorical_accuracy: 0.7300 - lr: 0.0010
# Epoch 39/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4987 - categorical_accuracy: 0.7881
# Epoch 39: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00039-0.49874-0.78806-0.68816-0.73000.h5
# 67/67 [==============================] - 26s 388ms/step - loss: 0.4987 - categorical_accuracy: 0.7881 - val_loss: 0.6882 - val_categorical_accuracy: 0.7300 - lr: 0.0010
# Epoch 40/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4820 - categorical_accuracy: 0.8090
# Epoch 40: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00040-0.48202-0.80896-0.47847-0.89000.h5
# 67/67 [==============================] - 25s 376ms/step - loss: 0.4820 - categorical_accuracy: 0.8090 - val_loss: 0.4785 - val_categorical_accuracy: 0.8900 - lr: 0.0010
# Epoch 41/50
# 67/67 [==============================] - ETA: 0s - loss: 0.5434 - categorical_accuracy: 0.7836
# Epoch 41: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00041-0.54336-0.78358-0.78751-0.72000.h5
# 67/67 [==============================] - 25s 369ms/step - loss: 0.5434 - categorical_accuracy: 0.7836 - val_loss: 0.7875 - val_categorical_accuracy: 0.7200 - lr: 0.0010
# Epoch 42/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4758 - categorical_accuracy: 0.8194
# Epoch 42: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00042-0.47578-0.81940-0.50285-0.82000.h5
# 67/67 [==============================] - 26s 387ms/step - loss: 0.4758 - categorical_accuracy: 0.8194 - val_loss: 0.5028 - val_categorical_accuracy: 0.8200 - lr: 0.0010
# Epoch 43/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4567 - categorical_accuracy: 0.8224
# Epoch 43: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00043-0.45675-0.82239-0.64386-0.79000.h5
# 67/67 [==============================] - 25s 375ms/step - loss: 0.4567 - categorical_accuracy: 0.8224 - val_loss: 0.6439 - val_categorical_accuracy: 0.7900 - lr: 0.0010
# Epoch 44/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4549 - categorical_accuracy: 0.8090
# Epoch 44: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00044-0.45486-0.80896-0.43887-0.86000.h5
# 67/67 [==============================] - 25s 376ms/step - loss: 0.4549 - categorical_accuracy: 0.8090 - val_loss: 0.4389 - val_categorical_accuracy: 0.8600 - lr: 0.0010
# Epoch 45/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4946 - categorical_accuracy: 0.7970
# Epoch 45: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00045-0.49459-0.79701-0.68885-0.74000.h5
# 67/67 [==============================] - 25s 374ms/step - loss: 0.4946 - categorical_accuracy: 0.7970 - val_loss: 0.6889 - val_categorical_accuracy: 0.7400 - lr: 0.0010
# Epoch 46/50
# 67/67 [==============================] - ETA: 0s - loss: 0.3919 - categorical_accuracy: 0.8582
# Epoch 46: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00046-0.39190-0.85821-0.51869-0.83000.h5
# 67/67 [==============================] - 25s 376ms/step - loss: 0.3919 - categorical_accuracy: 0.8582 - val_loss: 0.5187 - val_categorical_accuracy: 0.8300 - lr: 0.0010
# Epoch 47/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4212 - categorical_accuracy: 0.8343
# Epoch 47: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00047-0.42124-0.83433-1.06246-0.72000.h5
# 67/67 [==============================] - 25s 375ms/step - loss: 0.4212 - categorical_accuracy: 0.8343 - val_loss: 1.0625 - val_categorical_accuracy: 0.7200 - lr: 0.0010
# Epoch 48/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4850 - categorical_accuracy: 0.8164
# Epoch 48: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00048-0.48500-0.81642-0.59831-0.76000.h5
# 67/67 [==============================] - 25s 371ms/step - loss: 0.4850 - categorical_accuracy: 0.8164 - val_loss: 0.5983 - val_categorical_accuracy: 0.7600 - lr: 0.0010
# Epoch 49/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4535 - categorical_accuracy: 0.8164
# Epoch 49: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00049-0.45351-0.81642-0.81071-0.68000.h5
# 67/67 [==============================] - 26s 387ms/step - loss: 0.4535 - categorical_accuracy: 0.8164 - val_loss: 0.8107 - val_categorical_accuracy: 0.6800 - lr: 0.0010
# Epoch 50/50
# 67/67 [==============================] - ETA: 0s - loss: 0.4796 - categorical_accuracy: 0.7985
# Epoch 50: saving model to model_init_exp_16_2024-04-1008_29_53.019226/model-00050-0.47964-0.79851-0.63769-0.82000.h5
# 67/67 [==============================] - 25s 376ms/step - loss: 0.4796 - categorical_accuracy: 0.7985 - val_loss: 0.6377 - val_categorical_accuracy: 0.8200 - lr: 0.0010

# %%
# plt.figure(figsize=(20,6))
# ax1 = plt.subplot(121)
# ax1 = plt.plot(history.history['loss'])
# ax1 = plt.plot(history.history['val_loss'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'validation'], loc='lower left')
# ax2 = plt.subplot(122)
# ax2 = plt.plot(history.history['categorical_accuracy'])
# ax2 = plt.plot(history.history['val_categorical_accuracy'])
# plt.title('model accuracy')
# plt.ylabel('categorical_accuracy')
# plt.xlabel('epoch')
# plt.legend(['train', 'validation'], loc='lower left')

# %%
# Exp 2

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation,Dropout,GlobalAveragePooling3D,GRU,GlobalAveragePooling2D,LSTM,MaxPool2D,ConvLSTM2D,GlobalAveragePooling1D
from keras.layers import Conv3D, MaxPooling3D,Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers
from keras.applications import MobileNet

# %%
def generator(source_path, folder_list, batch_size):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    img_idx =[x for x in range(0,image_count)]
    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(t)//batch_size    # calculate the number of batches
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,image_count,image_width,image_height,channels)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,num_classes)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                    #crop the images and resize them. Note that the images are of 2 different shape
                    #and the conv3D will throw error if the inputs in a batch have different shapes

                    temp = cv2.resize(image,(image_width,image_height))
                    temp = temp/255 #Normalize data

                    batch_data[folder,idx,:,:,0] = (temp[:,:,0])  #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (temp[:,:,1])  #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (temp[:,:,2])  #normalise and feed in the image

                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do


        # write the code for the remaining data points which are left after full batches
        if (len(folder_list) != batch_size*num_batches):
            print("Batch: ",num_batches+1,"Index:", batch_size)
            batch_size = len(folder_list) - (batch_size*num_batches)
            batch_data = np.zeros((batch_size,image_count,image_width,image_height,channels)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,num_classes)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                    #crop the images and resize them. Note that the images are of 2 different shape
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    temp = cv2.resize(image,(image_width,image_height))
                    temp = temp/255 #Normalize data

                    batch_data[folder,idx,:,:,0] = (temp[:,:,0])
                    batch_data[folder,idx,:,:,1] = (temp[:,:,1])
                    batch_data[folder,idx,:,:,2] = (temp[:,:,2])

                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels

# %%
train_doc = np.random.permutation(open(f'Gesture_Recognition/Project_data/train.csv').readlines())
val_doc = np.random.permutation(open(f'Gesture_Recognition/Project_data/val.csv').readlines())

batch_size = 10 #experiment with the batch size
image_count = 30 # number of images to be used for each video
image_height=160
image_width=160
channels=3
num_classes=5 # number of classes
input_shape=(image_count,image_width,image_height,channels)
curr_dt_time = datetime.datetime.now()
train_path = f'Gesture_Recognition/Project_data/train'
val_path = f'Gesture_Recognition/Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 30 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 30

# %%
from keras.applications import ResNet152V2
# EfficientNetB7 with rnn gru units
model = Sequential()
model.add(TimeDistributed(ResNet152V2(weights='imagenet', include_top=False),input_shape=input_shape, name='ResNet152V2', trainable=False))
model.add(TimeDistributed(GlobalAveragePooling2D()))
model.add(TimeDistributed(Dense(64, activation='relu')))
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(GRU(128, return_sequences=True))
model.add(BatchNormalization())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234545216/234545216 [==============================] - 1s 0us/step

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
optimiser = optimizers.Adam() #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  ResNet152V2 (TimeDistribut  (None, 30, 5, 5, 2048)    58331648
#  ed)
#
#  time_distributed (TimeDist  (None, 30, 2048)          0
#  ributed)
#
#  time_distributed_1 (TimeDi  (None, 30, 64)            131136
#  stributed)
#
#  dense_1 (Dense)             (None, 30, 256)           16640
#
#  batch_normalization (Batch  (None, 30, 256)           1024
#  Normalization)
#
#  gru (GRU)                   (None, 30, 128)           148224
#
#  batch_normalization_1 (Bat  (None, 30, 128)           512
#  chNormalization)
#
#  flatten (Flatten)           (None, 3840)              0
#
#  dense_2 (Dense)             (None, 256)               983296
#
#  dense_3 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 59613765 (227.41 MB)
# Trainable params: 1281349 (4.89 MB)
# Non-trainable params: 58332416 (222.52 MB)
# _________________________________________________________________
# None

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %%
curr_dt_time = datetime.datetime.now()
model_name = 'model_init_exp_16' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'

if not os.path.exists(model_name):
    os.mkdir(model_name)

filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001, verbose=1) # write the REducelronplateau code here

callbacks_list = [checkpoint, LR]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history=model.fit(train_generator,
                  steps_per_epoch=steps_per_epoch,
                  epochs=num_epochs,
                  verbose=1,
                  callbacks=callbacks_list,
                  validation_data=val_generator,
                  validation_steps=validation_steps,
                  class_weight=None,
                  workers=1,
                  initial_epoch=0,
                  max_queue_size=3000)
# Out:
# Source path =  Gesture_Recognition/Project_data/train ; batch size = 10
# Epoch 1/30
# 64/67 [===========================>..] - ETA: 7s - loss: 3.0332 - categorical_accuracy: 0.4141Batch:  67 Index: 10
# 67/67 [==============================] - ETA: 0s - loss: 3.0352 - categorical_accuracy: 0.4178Source path =  Gesture_Recognition/Project_data/val ; batch size = 10
#
# Epoch 1: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00001-3.03524-0.41780-3.03041-0.41000.h5
# 67/67 [==============================] - 212s 3s/step - loss: 3.0352 - categorical_accuracy: 0.4178 - val_loss: 3.0304 - val_categorical_accuracy: 0.4100 - lr: 0.0010
# Epoch 2/30
# 67/67 [==============================] - ETA: 0s - loss: 3.9385 - categorical_accuracy: 0.4030
# Epoch 2: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00002-3.93854-0.40299-6.40994-0.27000.h5
# 67/67 [==============================] - 72s 1s/step - loss: 3.9385 - categorical_accuracy: 0.4030 - val_loss: 6.4099 - val_categorical_accuracy: 0.2700 - lr: 0.0010
# Epoch 3/30
# 67/67 [==============================] - ETA: 0s - loss: 4.4806 - categorical_accuracy: 0.3980
# Epoch 3: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00003-4.48059-0.39801-8.23755-0.30000.h5
# 67/67 [==============================] - 72s 1s/step - loss: 4.4806 - categorical_accuracy: 0.3980 - val_loss: 8.2376 - val_categorical_accuracy: 0.3000 - lr: 0.0010
# Epoch 4/30
# 67/67 [==============================] - ETA: 0s - loss: 4.1317 - categorical_accuracy: 0.4129
# Epoch 4: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00004-4.13173-0.41294-6.09594-0.40000.h5
# 67/67 [==============================] - 66s 991ms/step - loss: 4.1317 - categorical_accuracy: 0.4129 - val_loss: 6.0959 - val_categorical_accuracy: 0.4000 - lr: 0.0010
# Epoch 5/30
# 67/67 [==============================] - ETA: 0s - loss: 2.8693 - categorical_accuracy: 0.4826
# Epoch 5: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00005-2.86929-0.48259-3.05285-0.48000.h5
# 67/67 [==============================] - 71s 1s/step - loss: 2.8693 - categorical_accuracy: 0.4826 - val_loss: 3.0529 - val_categorical_accuracy: 0.4800 - lr: 0.0010
# Epoch 6/30
# 67/67 [==============================] - ETA: 0s - loss: 1.9882 - categorical_accuracy: 0.5622
# Epoch 6: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00006-1.98821-0.56219-3.00234-0.46000.h5
# 67/67 [==============================] - 74s 1s/step - loss: 1.9882 - categorical_accuracy: 0.5622 - val_loss: 3.0023 - val_categorical_accuracy: 0.4600 - lr: 0.0010
# Epoch 7/30
# 67/67 [==============================] - ETA: 0s - loss: 1.7467 - categorical_accuracy: 0.5721
# Epoch 7: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00007-1.74674-0.57214-2.26785-0.50000.h5
# 67/67 [==============================] - 73s 1s/step - loss: 1.7467 - categorical_accuracy: 0.5721 - val_loss: 2.2678 - val_categorical_accuracy: 0.5000 - lr: 0.0010
# Epoch 8/30
# 67/67 [==============================] - ETA: 0s - loss: 1.5904 - categorical_accuracy: 0.5920
# Epoch 8: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00008-1.59039-0.59204-1.64959-0.65000.h5
# 67/67 [==============================] - 74s 1s/step - loss: 1.5904 - categorical_accuracy: 0.5920 - val_loss: 1.6496 - val_categorical_accuracy: 0.6500 - lr: 0.0010
# Epoch 9/30
# 67/67 [==============================] - ETA: 0s - loss: 0.9819 - categorical_accuracy: 0.6567
# Epoch 9: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00009-0.98188-0.65672-2.28757-0.52000.h5
# 67/67 [==============================] - 72s 1s/step - loss: 0.9819 - categorical_accuracy: 0.6567 - val_loss: 2.2876 - val_categorical_accuracy: 0.5200 - lr: 0.0010
# Epoch 10/30
# 67/67 [==============================] - ETA: 0s - loss: 1.1986 - categorical_accuracy: 0.5920
# Epoch 10: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00010-1.19855-0.59204-2.50404-0.57000.h5
# 67/67 [==============================] - 66s 982ms/step - loss: 1.1986 - categorical_accuracy: 0.5920 - val_loss: 2.5040 - val_categorical_accuracy: 0.5700 - lr: 0.0010
# Epoch 11/30
# 67/67 [==============================] - ETA: 0s - loss: 0.9209 - categorical_accuracy: 0.7164
# Epoch 11: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00011-0.92088-0.71642-1.66463-0.55000.h5
# 67/67 [==============================] - 65s 975ms/step - loss: 0.9209 - categorical_accuracy: 0.7164 - val_loss: 1.6646 - val_categorical_accuracy: 0.5500 - lr: 0.0010
# Epoch 12/30
# 67/67 [==============================] - ETA: 0s - loss: 0.7313 - categorical_accuracy: 0.7313
# Epoch 12: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00012-0.73132-0.73134-1.85292-0.55000.h5
# 67/67 [==============================] - 71s 1s/step - loss: 0.7313 - categorical_accuracy: 0.7313 - val_loss: 1.8529 - val_categorical_accuracy: 0.5500 - lr: 0.0010
# Epoch 13/30
# 67/67 [==============================] - ETA: 0s - loss: 0.8352 - categorical_accuracy: 0.6617
# Epoch 13: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00013-0.83518-0.66169-2.17094-0.57000.h5
# 67/67 [==============================] - 65s 978ms/step - loss: 0.8352 - categorical_accuracy: 0.6617 - val_loss: 2.1709 - val_categorical_accuracy: 0.5700 - lr: 0.0010
# Epoch 14/30
# 67/67 [==============================] - ETA: 0s - loss: 1.0247 - categorical_accuracy: 0.6517
# Epoch 14: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00014-1.02472-0.65174-2.15303-0.54000.h5
# 67/67 [==============================] - 66s 987ms/step - loss: 1.0247 - categorical_accuracy: 0.6517 - val_loss: 2.1530 - val_categorical_accuracy: 0.5400 - lr: 0.0010
# Epoch 15/30
# 67/67 [==============================] - ETA: 0s - loss: 0.7841 - categorical_accuracy: 0.7264
# Epoch 15: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00015-0.78413-0.72637-2.13703-0.56000.h5
# 67/67 [==============================] - 75s 1s/step - loss: 0.7841 - categorical_accuracy: 0.7264 - val_loss: 2.1370 - val_categorical_accuracy: 0.5600 - lr: 0.0010
# Epoch 16/30
# 67/67 [==============================] - ETA: 0s - loss: 0.6127 - categorical_accuracy: 0.7313
# Epoch 16: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00016-0.61271-0.73134-2.17160-0.48000.h5
# 67/67 [==============================] - 73s 1s/step - loss: 0.6127 - categorical_accuracy: 0.7313 - val_loss: 2.1716 - val_categorical_accuracy: 0.4800 - lr: 0.0010
# Epoch 17/30
# 67/67 [==============================] - ETA: 0s - loss: 0.7683 - categorical_accuracy: 0.7363
# Epoch 17: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00017-0.76827-0.73632-2.07177-0.56000.h5
# 67/67 [==============================] - 76s 1s/step - loss: 0.7683 - categorical_accuracy: 0.7363 - val_loss: 2.0718 - val_categorical_accuracy: 0.5600 - lr: 0.0010
# Epoch 18/30
# 67/67 [==============================] - ETA: 0s - loss: 0.6705 - categorical_accuracy: 0.7662
# Epoch 18: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00018-0.67052-0.76617-2.25803-0.57000.h5
# 67/67 [==============================] - 72s 1s/step - loss: 0.6705 - categorical_accuracy: 0.7662 - val_loss: 2.2580 - val_categorical_accuracy: 0.5700 - lr: 0.0010
# Epoch 19/30
# 67/67 [==============================] - ETA: 0s - loss: 0.7348 - categorical_accuracy: 0.7711
# Epoch 19: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00019-0.73485-0.77114-2.74618-0.53000.h5
# 67/67 [==============================] - 72s 1s/step - loss: 0.7348 - categorical_accuracy: 0.7711 - val_loss: 2.7462 - val_categorical_accuracy: 0.5300 - lr: 0.0010
# Epoch 20/30
# 67/67 [==============================] - ETA: 0s - loss: 0.7809 - categorical_accuracy: 0.7164
# Epoch 20: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00020-0.78088-0.71642-2.04092-0.53000.h5
# 67/67 [==============================] - 70s 1s/step - loss: 0.7809 - categorical_accuracy: 0.7164 - val_loss: 2.0409 - val_categorical_accuracy: 0.5300 - lr: 0.0010
# Epoch 21/30
# 67/67 [==============================] - ETA: 0s - loss: 0.5747 - categorical_accuracy: 0.7960
# Epoch 21: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00021-0.57467-0.79602-1.80524-0.56000.h5
# 67/67 [==============================] - 76s 1s/step - loss: 0.5747 - categorical_accuracy: 0.7960 - val_loss: 1.8052 - val_categorical_accuracy: 0.5600 - lr: 0.0010
# Epoch 22/30
# 67/67 [==============================] - ETA: 0s - loss: 0.7043 - categorical_accuracy: 0.7662
# Epoch 22: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00022-0.70435-0.76617-1.85094-0.60000.h5
# 67/67 [==============================] - 75s 1s/step - loss: 0.7043 - categorical_accuracy: 0.7662 - val_loss: 1.8509 - val_categorical_accuracy: 0.6000 - lr: 0.0010
# Epoch 23/30
# 67/67 [==============================] - ETA: 0s - loss: 0.5330 - categorical_accuracy: 0.7960
# Epoch 23: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00023-0.53298-0.79602-2.43316-0.58000.h5
# 67/67 [==============================] - 74s 1s/step - loss: 0.5330 - categorical_accuracy: 0.7960 - val_loss: 2.4332 - val_categorical_accuracy: 0.5800 - lr: 0.0010
# Epoch 24/30
# 67/67 [==============================] - ETA: 0s - loss: 0.5581 - categorical_accuracy: 0.7711
# Epoch 24: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00024-0.55805-0.77114-1.63097-0.62000.h5
# 67/67 [==============================] - 73s 1s/step - loss: 0.5581 - categorical_accuracy: 0.7711 - val_loss: 1.6310 - val_categorical_accuracy: 0.6200 - lr: 0.0010
# Epoch 25/30
# 67/67 [==============================] - ETA: 0s - loss: 0.3758 - categorical_accuracy: 0.8706
# Epoch 25: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00025-0.37577-0.87065-1.84735-0.61000.h5
# 67/67 [==============================] - 65s 981ms/step - loss: 0.3758 - categorical_accuracy: 0.8706 - val_loss: 1.8474 - val_categorical_accuracy: 0.6100 - lr: 0.0010
# Epoch 26/30
# 67/67 [==============================] - ETA: 0s - loss: 0.6017 - categorical_accuracy: 0.7811
# Epoch 26: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00026-0.60173-0.78109-2.04013-0.55000.h5
# 67/67 [==============================] - 65s 974ms/step - loss: 0.6017 - categorical_accuracy: 0.7811 - val_loss: 2.0401 - val_categorical_accuracy: 0.5500 - lr: 0.0010
# Epoch 27/30
# 67/67 [==============================] - ETA: 0s - loss: 0.5385 - categorical_accuracy: 0.8010
# Epoch 27: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00027-0.53852-0.80100-2.64104-0.54000.h5
# 67/67 [==============================] - 65s 979ms/step - loss: 0.5385 - categorical_accuracy: 0.8010 - val_loss: 2.6410 - val_categorical_accuracy: 0.5400 - lr: 0.0010
# Epoch 28/30
# 67/67 [==============================] - ETA: 0s - loss: 0.6244 - categorical_accuracy: 0.7761
# Epoch 28: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00028-0.62436-0.77612-2.01518-0.56000.h5
# 67/67 [==============================] - 76s 1s/step - loss: 0.6244 - categorical_accuracy: 0.7761 - val_loss: 2.0152 - val_categorical_accuracy: 0.5600 - lr: 0.0010
# Epoch 29/30
# 67/67 [==============================] - ETA: 0s - loss: 0.5452 - categorical_accuracy: 0.8010
# Epoch 29: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00029-0.54521-0.80100-2.28198-0.51000.h5
# 67/67 [==============================] - 72s 1s/step - loss: 0.5452 - categorical_accuracy: 0.8010 - val_loss: 2.2820 - val_categorical_accuracy: 0.5100 - lr: 0.0010
# Epoch 30/30
# 67/67 [==============================] - ETA: 0s - loss: 0.6213 - categorical_accuracy: 0.7612
# Epoch 30: saving model to model_init_exp_16_2024-04-1007_44_11.751912/model-00030-0.62135-0.76119-1.86134-0.63000.h5
# 67/67 [==============================] - 72s 1s/step - loss: 0.6213 - categorical_accuracy: 0.7612 - val_loss: 1.8613 - val_categorical_accuracy: 0.6300 - lr: 0.0010

# %%
plt.figure(figsize=(20,6))
ax1 = plt.subplot(121)
ax1 = plt.plot(history.history['loss'])
ax1 = plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
ax2 = plt.subplot(122)
ax2 = plt.plot(history.history['categorical_accuracy'])
ax2 = plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('categorical_accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
